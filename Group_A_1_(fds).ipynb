# %%
cri=[]
bad=[]
fot=[]
c = int(input("enter no. of students who play cricket: "))
b = int(input("enter no. of students who play badminton: "))
f = int(input("enter no. of students who play football: "))

for i in range (c):
    cri.append(int(input(f"Enter the roll no.s of student {i+1} who plays cricket: ")))
for i in range (b):
    bad.append(int(input(f"Enter the roll no.s of student {i+1} who plays badminton: ")))
for i in range (f):
    fot.append(int(input(f"Enter the roll no.s of student {i+1} who plays football: ")))

    m=cri.count(i)
    if m>1:
        cri.remove(i)
for i in bad:
    m=bad.count(i)
    if m>1:
        bad.remove(i)
for i in fot:
    m=fot.count(i)
    if m>1:
        fot.remove(i)
    
cri.sort()
bad.sort()
fot.sort()
 
print("\nlist of students who play cricket:", cri)
print("list of students who play badminton:", bad)
print("list of students who play football:",fot )


# BOTH CRICKET AND BADMINTON
cnb=[]
for i in cri:
    for j in bad:
        if i==j:
            cnb.append(i)
            
print(f"\nList of students who play both cricket and badmintion are: {cnb}")


# EITHR CRICKET OR BADMINTON BUT NOT BOTH
cub=[]
cub = []
for i in cri:
    cub.append(i)
    
for i in bad:
    for j in cub:
        if i!=j:
            cub.append(i)
            break
            
for i in cub:
    p = cub.count(i)
    if p>1:
        cub.remove(i)
        cub.remove(i)
        
cub.sort()
print(f"List of students who play either cricket or badminton but not both:{cub}")


#NEITHER CRICKET NOR BADMINTON

ncnb = []
for i in fot:
    ncnb.append(i)
    
a=[]
for k in fot:
    for l in cub:
        if l==k:
            a.append(l)           
for v in a:
    ncnb.remove(v)
    
count1=0
t=0
for i in ncnb:
    if t==0:
        count1+=1
print(f"Number of students who play neither cricket nor badminton are:{count1}")


#CRICKET AND FOOTBALL BUT NOT BADMINTON

cnf=[]
for i in cri:
    for j in fot:
        if i==j:
            cnf.append(i)

for m in cnf:
    for n in bad:
        if m==n:
            cnf.remove(m)
            
count=0
for d in cnf:
    if 1>0:
        count+=1       
print(f"Number of students who play cricket and football but not badminton are:{count}")
# Out:
# enter no. of students who play cricket: 6
# enter no. of students who play badminton: 6
# enter no. of students who play football: 6
# Enter the roll no.s of student 1 who plays cricket: 1
# Enter the roll no.s of student 2 who plays cricket: 3
# Enter the roll no.s of student 3 who plays cricket: 5
# Enter the roll no.s of student 4 who plays cricket: 2
# Enter the roll no.s of student 5 who plays cricket: 4
# Enter the roll no.s of student 6 who plays cricket: 6
# Enter the roll no.s of student 1 who plays badminton: 7
# Enter the roll no.s of student 2 who plays badminton: 9
# Enter the roll no.s of student 3 who plays badminton: 10
# Enter the roll no.s of student 4 who plays badminton: 2
# Enter the roll no.s of student 5 who plays badminton: 4
# Enter the roll no.s of student 6 who plays badminton: 12
# Enter the roll no.s of student 1 who plays football: 15
# Enter the roll no.s of student 2 who plays football: 4
# Enter the roll no.s of student 3 who plays football: 10
# Enter the roll no.s of student 4 who plays football: 2
# Enter the roll no.s of student 5 who plays football: 11
# Enter the roll no.s of student 6 who plays football: 13
#
# list of students who play cricket: [1, 2, 3, 4, 5, 6]
# list of students who play badminton: [2, 4, 7, 9, 10, 12]
# list of students who play football: [2, 4, 10, 11, 13, 15]
#
# List of students who play both cricket and badmintion are: [2, 4]
# List of students who play either cricket or badminton but not both:[1, 3, 5, 6, 7, 9, 10, 12]
# Number of students who play neither cricket nor badminton are:5
# Number of students who play cricket and football but not badminton are:1
